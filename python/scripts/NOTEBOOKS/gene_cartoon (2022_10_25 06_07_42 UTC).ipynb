# %%
from dna_features_viewer import GraphicFeature, GraphicRecord
from matplotlib import pyplot as plt
import pandas as pd

# %%
features=[
    GraphicFeature(start=0, end=20, strand=+1, color="#ffd700", 
                   label="Small feature"),
    GraphicFeature(start=20, end=500, strand=+1, color="#ffcccc",
                   label="Gene 1 with a very long name"),
    GraphicFeature(start=400, end=700, strand=-1, color="#cffccc",
                   label="Gene 2"),
    GraphicFeature(start=600, end=900, strand=+1, color="#ccccff",
                   label="Gene 3")
]
record = GraphicRecord(sequence_length=1000, features=features)
record.plot(figure_width=5)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1bbdb08ff08>,
#  ({GF(Small feature, 0-20 (1)): 0,
#    GF(Gene 1 with a very long name, 20-500 (1)): 0,
#    GF(Gene 2, 400-700 (-1)): 1.0,
#    GF(Gene 3, 600-900 (1)): 0},
#   {GF(Gene 1 with a very long name, 20-500 (1)): {'feature_y': 0,
#     'annotation_y': 2.0},
#    GF(Small feature, 0-20 (1)): {'feature_y': 0, 'annotation_y': 1.0}}))

# %%
features=[
    GraphicFeature(start=148, end=278, strand=-1, color="#ffd700",thickness=10,
                   label="UTR"),
    GraphicFeature(start=279, end=1465, strand=-1, color="#ffcccc",
                   label="bzp4"),
    GraphicFeature(start=1466, end=2189, strand=-1, color="#ffd700",thickness=10,
                   ),
    GraphicFeature(start=4079, end=4097, color="#ff4d00",
                   label="Small Deletion"),
    GraphicFeature(start=5035, end=5116, strand=-1, color="#ffd700",thickness=10,
                   ),
    GraphicFeature(start=5117, end=7774, strand=-1, color="#ccccff",
                   label="hsp78"),
    GraphicFeature(start=7775, end=7863, strand=-1, color="#ffd700",thickness=10,
                   )
]
record = GraphicRecord(sequence_length=8064, features=features)
record.plot(figure_width=10);

plt.savefig("C:/Users/Thomas/Pictures/scientific figures/bzp4_hsp78_gene_model_ftc.png", 
            dpi = 100, bbox_inches = "tight")

# %%
features=[
    GraphicFeature(start=148, end=278, strand=-1, color="#ffd700", thickness=10,
                   label="UTR"),
    GraphicFeature(start=279, end=1465, strand=-1, color="#ffcccc",
                   label = "bzp4"),
    GraphicFeature(start=1466, end=2095, strand=-1, color="#ffd700",thickness=10, open_right = True,
                   ),
    GraphicFeature(start=2096, end=2197, color="#65da40",thickness=10, open_right = True, open_left= True,
                   label = "Portion of UTR Deleted"),
    GraphicFeature(start=2096, end=3893, color="#ff4d00",
                   label="Deletion"),
    GraphicFeature(start=5035, end=5116, strand=-1, color="#ffd700",thickness=10,
                   ),
    GraphicFeature(start=5117, end=7774, strand=-1, color="#ccccff",
                   label="hsp78"),
    GraphicFeature(start=7775, end=7863, strand=-1, color="#ffd700",thickness=10,
                   )
]
record = GraphicRecord(sequence_length=8064, features=features)
record.plot(figure_width=10);

plt.savefig("C:/Users/Thomas/Pictures/scientific figures/bzp4_hsp78_gene_model_bt22.png", 
            dpi = 100, bbox_inches = "tight")

# %%
features=[
    GraphicFeature(start=148, end=278, strand=-1, color="#ffd700", thickness=10,
                   label="UTR"),
    GraphicFeature(start=279, end=1465, strand=-1, color="#ffcccc",
                   label = "bzp4"),
    GraphicFeature(start=1466, end=2095, strand=-1, color="#ffd700",thickness=10, open_right = True,
                   ),
    GraphicFeature(start=2096, end=2197, color="#ffc80f", open_right = True, 
                   label = "UTR Deletion"),
    GraphicFeature(start=2198, end=3893, color="#ff4d00", open_left= True,
                   label="Deletion"),
    GraphicFeature(start=5035, end=5116, strand=-1, color="#ffd700",thickness=10,
                   ),
    GraphicFeature(start=5117, end=7774, strand=-1, color="#ccccff",
                   label="hsp78"),
    GraphicFeature(start=7775, end=7863, strand=-1, color="#ffd700",thickness=10,
                   )
]
record = GraphicRecord(sequence_length=8064, features=features)
record.plot(figure_width=10);

plt.savefig("C:/Users/Thomas/Pictures/scientific figures/bzp4_hsp78_gene_model_bt22.png", 
            dpi = 100, bbox_inches = "tight")

# %% [markdown]
# # C. neoformans model

# %% [markdown]
# ## Ftc555-1

# %%
features=[
    GraphicFeature(start=0, end=87, strand=1, color="#ffd700", thickness=10,
                  ), # 5'
    GraphicFeature(start=88, end=2746, strand=1, color="#0ae4f6",
                   label = "HSP78"), # cdr
    GraphicFeature(start=2747, end=2827, strand=1, color="#ffd700",thickness=10, open_right = True,
                   ), #3'
    GraphicFeature(start=5770, end=6106, strand=1,color="#ffd700", thickness = 10, 
                   ), # 5'
    GraphicFeature(start=6107, end=6215, strand=1,color="#35f60a",
                   ), # cdr
    GraphicFeature(start=6216, end=6400, strand=1, color="#ffd700",thickness=10,
                   ), # 5'
    GraphicFeature(start=6402, end=7588, strand=1, color="#35f60a",
                   label="BZP4"), # cdr
    GraphicFeature(start=7589, end=7717, strand=1, color="#ffd700",thickness=10,
                   ), # 3'
    GraphicFeature(start=9490, end=9763, strand=1, color="#ffd700",thickness=10,
                  ), # 5'
    GraphicFeature(start=9764, end=10165, strand=1, color="#950af6",
                  ), # cdr
    GraphicFeature(start=10166, end=10275, strand=1, color="#ffd700",thickness=10,
                  ), # 5'
    GraphicFeature(start=10276, end=15876, strand=1, color="#950af6",
                  label="SSD1"), # cdr
    GraphicFeature(start=15877, end=15977, strand=1, color="#ffd700",thickness=10,
                  ), # 3'
    GraphicFeature(start=15978, end=16035, strand=1, color="#950af6",
                  ), # cdr
    GraphicFeature(start=16035, end=17308, strand=1, color="#ffd700",thickness=10,
                  ), # 3'
]
record = GraphicRecord(sequence_length=17518, features=features)
record.plot(figure_width=17);

plt.savefig("C:/Users/Thomas/Pictures/scientific figures/bzp4_gene_region_model_ftc555-1_cneo.png", 
            dpi = 100, bbox_inches = "tight")

# %% [markdown]
# ## Bt22

# %%
features=[
    GraphicFeature(start=0, end=87, strand=1, color="#ffd700", thickness=10,
                  ), # 5'
    GraphicFeature(start=88, end=2746, strand=1, color="#0ae4f6",
                   label = "HSP78"), # cdr
    GraphicFeature(start=2747, end=2827, strand=1, color="#ffd700",thickness=10, open_right = True,
                   ), #3'
    GraphicFeature(start=3973, end=5669, color="#ff4d00", open_left= True,
                   label="Deletion"),
    GraphicFeature(start=5670, end=5769, color="#ffc80f", open_right = True, 
                   label = "UTR Deletion"),
    GraphicFeature(start=5770, end=6106, strand=1,color="#ffd700", thickness = 10, 
                   ), # 5'
    GraphicFeature(start=6107, end=6215, strand=1,color="#35f60a",
                   ), # cdr
    GraphicFeature(start=6216, end=6400, strand=1, color="#ffd700",thickness=10,
                   ), # 5'
    GraphicFeature(start=6402, end=7588, strand=1, color="#35f60a",
                   label="BZP4"), # cdr
    GraphicFeature(start=7589, end=7717, strand=1, color="#ffd700",thickness=10,
                   ), # 3'
    GraphicFeature(start=9490, end=9763, strand=1, color="#ffd700",thickness=10,
                  ), # 5'
    GraphicFeature(start=9764, end=10165, strand=1, color="#950af6",
                  ), # cdr
    GraphicFeature(start=10166, end=10275, strand=1, color="#ffd700",thickness=10,
                  ), # 5'
    GraphicFeature(start=10276, end=15876, strand=1, color="#950af6",
                  label="SSD1"), # cdr
    GraphicFeature(start=15877, end=15977, strand=1, color="#ffd700",thickness=10,
                  ), # 3'
    GraphicFeature(start=15978, end=16035, strand=1, color="#950af6",
                  ), # cdr
    GraphicFeature(start=16035, end=17308, strand=1, color="#ffd700",thickness=10,
                  ), # 3'
]
record = GraphicRecord(sequence_length=17518, features=features)
record.plot(figure_width=17);

plt.savefig("C:/Users/Thomas/Pictures/scientific figures/bzp4_gene_region_model_bt22_cneo.png", 
            dpi = 100, bbox_inches = "tight")

# %% [markdown]
# # C. deneoformans model

# %% [markdown]
# ## XL280

# %%
features=[
    GraphicFeature(start=0, end=71, strand=1, color="#ffd700", thickness=10,
                  ), # 5'
    GraphicFeature(start=72, end=2729, strand=1, color="#0ae4f6",
                   label = "HSP78"), # cdr
    GraphicFeature(start=2730, end=2795, strand=1, color="#ffd700",thickness=10, open_right = True,
                   ), #3'
    GraphicFeature(start=5855, end=6033, strand=1,color="#ffd700", thickness = 10, 
                   ), # 5'
    GraphicFeature(start=6034, end=6139, strand=1,color="#35f60a",
                   ), # cdr
    GraphicFeature(start=6140, end=6324, strand=1, color="#ffd700",thickness=10,
                   ), # 5'
    GraphicFeature(start=6325, end=7160, strand=1, color="#35f60a",
                   label="BZP4"), # cdr
    GraphicFeature(start=7161, end=7201, strand=1, color="#ffd700",thickness=10,
                   ), # 3'
     GraphicFeature(start=7202, end=7212, color="#ffc80f", open_right = True, 
                   ),
    GraphicFeature(start=11058, end=11178, strand=1, color="#ffd700",thickness=10,
                  ), # 5'
    GraphicFeature(start=11179, end=11579, strand=1, color="#950af6",
                  ), # cdr
    GraphicFeature(start=11580, end=11689, strand=1, color="#ffd700",thickness=10,
                  ), # 5'
    GraphicFeature(start=11690, end=17481, strand=1, color="#950af6",
                  label="SSD1"), # cdr
    GraphicFeature(start=17482, end=17701, strand=1, color="#ffd700",thickness=10,
                  ), # 3'
]
record = GraphicRecord(sequence_length=17702, features=features)
record.plot(figure_width=17);

plt.savefig("C:/Users/Thomas/Pictures/scientific figures/bzp4_gene_region_model_XL280_cdeneo.png", 
            dpi = 100, bbox_inches = "tight")

# %% [markdown]
# ## 431

# %%
features=[
    GraphicFeature(start=0, end=71, strand=1, color="#ffd700", thickness=10,
                  ), # 5'
    GraphicFeature(start=72, end=2729, strand=1, color="#0ae4f6",
                   label = "HSP78"), # cdr
    GraphicFeature(start=2730, end=2795, strand=1, color="#ffd700",thickness=10, open_right = True,
                   ), #3'
    GraphicFeature(start=5855, end=6033, strand=1,color="#ffd700", thickness = 10, 
                   ), # 5'
    GraphicFeature(start=6034, end=6139, strand=1,color="#35f60a",
                   ), # cdr
    GraphicFeature(start=6140, end=6324, strand=1, color="#ffd700",thickness=10,
                   ), # 5'
    GraphicFeature(start=6325, end=7160, strand=1, color="#35f60a",
                   label="BZP4"), # cdr
    GraphicFeature(start=7161, end=7201, strand=1, color="#ffd700",thickness=10,
                   ), # 3'
     GraphicFeature(start=7202, end=7212, color="#ffc80f", open_right = True, 
                   ),
    GraphicFeature(start=7213, end=10603, color="#ff4d00", open_left= True,
                   label="Low Coverage"),
    GraphicFeature(start=11058, end=11178, strand=1, color="#ffd700",thickness=10,
                  ), # 5'
    GraphicFeature(start=11179, end=11579, strand=1, color="#950af6",
                  ), # cdr
    GraphicFeature(start=11580, end=11689, strand=1, color="#ffd700",thickness=10,
                  ), # 5'
    GraphicFeature(start=11690, end=17481, strand=1, color="#950af6",
                  label="SSD1"), # cdr
    GraphicFeature(start=17482, end=17701, strand=1, color="#ffd700",thickness=10,
                  ), # 3'
]
record = GraphicRecord(sequence_length=17702, features=features)
record.plot(figure_width=17);

plt.savefig("C:/Users/Thomas/Pictures/scientific figures/bzp4_gene_region_model_431_cdeneo.png", 
            dpi = 100, bbox_inches = "tight")

# %%
bzp_hsp_file = "C:/Users/Thomas/Documents/bzp_hsp_full_region.txt"

# %%
bzp_hsp_df = pd.read_csv(bzp_hsp_file, header = None)

bzp_hsp = bzp_hsp_df.to_string(header = False, index = False)

# %%
features_long =[
    GraphicFeature(start=148, end=278, strand=-1, color="#ffd700", thickness=20, fontdict={'size':15},
                   label="UTR"),
    GraphicFeature(start=279, end=1465, strand=-1, color="#ffcccc",thickness=28,fontdict={'size':15},
                   label = "Bzp4"),
    GraphicFeature(start=1466, end=2095, strand=-1, color="#ffd700",thickness=20, open_right = True,fontdict={'size':15},
                   ),
    GraphicFeature(start=2096, end=2197, color="#ffc80f", open_right = True, thickness=28,fontdict={'size':15},
                   label = "UTR Deletion"),
    GraphicFeature(start=2198, end=3893, color="#ff4d00", open_left= True,thickness=28,fontdict={'size':15},
                   label="Deletion"),
    GraphicFeature(start=5035, end=5116, strand=-1, color="#ffd700",thickness=20,fontdict={'size':15},
                   ),
    GraphicFeature(start=5117, end=7774, strand=-1, color="#ccccff",fontdict={'size':15},
                   label="Hsp78"),
    GraphicFeature(start=7775, end=7863, strand=-1, color="#ffd700",thickness=20,fontdict={'size':15},
                   )
]

# %%
record_long = GraphicRecord(sequence=bzp_hsp, features = features_long)

# %%
record_long.plot_on_multiple_lines(nucl_per_line = 750, plot_sequence = True, figure_width = 50, n_lines = 14);

plt.savefig("C:/Users/Thomas/Pictures/scientific figures/bzp4_hsp78_gene_model_seq.png", 
            dpi = 100, bbox_inches = "tight")
